# %% [markdown]
# <a href="https://colab.research.google.com/github/ustab/NOTES-FROM-LECTURERS/blob/main/Untitled101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IF ELIF ELSE KONUSU
'''
if True:
  print("kosul dogru")
  print("halen if blogunun icindeyiz")

if False:
  print("kosul dogru")
  print("halen if blogunun icindeyiz")

a = 5
b = 7
if a == b:
  print("a = b")

a = 5
b = 7
if not a == b:
  print("a = b")

a = 5
b = 7
if a != b:
  print("a = b")

a = 5
b = 7
if a < b:
  print("a < b")

a = 5
b = 7
if not a > b:
  print("a > b")

a = 5
b = 7
if a == b:
  print("a = b")
else:
  print("a 'b ye esit degildir")

a = 5
b = 7
if a == b:
  print("a = b")

renk = input("renk:")

if renk == "beyaz" :
  print("mendilim beyazdir kalbim kalbine ayandir")
elif renk == "sari":
  print("sarardim soldum, nettin bana boyle")
elif renk == "mavi":
  print("mavi mavi masmavi gozlerin boncuk mavi")
elif renk == "siyah":
  print("sen aglama komur gozlum")
else:
  print("nerden buldun bu gicik rengi")

a = 5
b = 7
c=4

if a < b and not c > a:
  print("bildik arkadas")

else:
  print("sacmaladin gene")

isim="python"
i=input("harf tahmini yap:")
if i in isim:
  print("bravo bildin var")
else:
  print("karavana sallama")
i=input("tekrar tahmin et:")
if i in isim:
  print("bravo sonunda fareyi yakaladin")
else:
  print("üzgunum arpayi yedin")
  
a="python"
b="pytho"
b+="n"
#if not a==b:
#if True:
if a==b:
  print("dogru bildin")
else:
  print("yanildin, bu gidisle daha cok yanilirsin")
